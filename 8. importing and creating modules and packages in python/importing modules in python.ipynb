# %%
import math
math.sqrt(9)

# %%
from math import sqrt,pi
print(pi)
print(sqrt(25))

# %%
import numpy as np
np.array([1,2,3])

# %%
from math import *
print(sqrt(36))

# %%
from package.maths import addition
addition(2,3)

# %%
from package import maths
maths.addition(2,3)

# %%
from package import maths
print(maths.addition(8,9))
print(maths.subt(9,8))

# %%
### standard libary overview
"""" libaries are vast collection of modules and packages that bundled with python"""

# %%
import array
arr=array.array('i',[1,2,3,4])
print(arr)

# %%
### random 
import random
print(random.randint(1,10))
print(random.choice(["apple","banana","cherry"]))

# %%
### file and directory access
import os
print(os.getcwd())

# %%
os.mkdir("test_dir")

# %%
### high level operations in files and collection of files
import shutil
shutil.copyfile("test_dir\text.txt","test_dir\destination.txt")

# %%
## data seralization
import json
data={"name":"a","age":20}
json_str=json.dumps(data)
print(json_str)
passed_data=json.loads(json_str)
print(passed_data)
print(type(passed_data))
# Out:
# {"name": "a", "age": 20}
# {'name': 'a', 'age': 20}
# <class 'dict'>

# %%
### csv files
import csv
with open('example.csv',mode="w",newline="") as file:
    writer=csv.writer(file)
    writer.writerow(["name","age"])
    writer.writerow(["aadarsh",32])
with open('example.csv',mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['aadarsh', '32']

# %%
## datetime
from datetime import datetime,timedelta
now=datetime.now()
print(now)
yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2026-02-19 15:01:23.669437
# 2026-02-18 15:01:23.669437

# %%
### time
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1771493541.4129124
# 1771493543.4154994

# %%
### regular expression 
import re
pattern=r'\d+'
text='there are 123 apples 456'
match=re.search(pattern,text)
print(match.group())
# Out:
# 123
