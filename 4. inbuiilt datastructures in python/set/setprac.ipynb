# %%
#creating set
my_set={1,2,3}
print(my_set)
# Out:
# {1, 2, 3}

# %%
set1=set()#empty set creation
s=set([1,2,2,3,4,4])
print(s)
# Out:
# {1, 2, 3, 4}

# %%
#operations 
#adding and removing elements
s.add(7)
print(s)
# Out:
# {1, 2, 3, 4, 7}

# %%
s.remove(4)
s
# Out:
# {1, 2, 3, 7}

# %%
s.discard(11)#here 11 is not present even it doesnot shows the error while using the dicard function

# %%
##pop method
removed=s.pop()
print(removed)
# Out:
# 1

# %%
##clear method 
s.clear()

# %%
#set memebership test
s={1,2,3,4,5}
print(3 in s)
print(4 in s)
# Out:
# True
# True

# %%
#mathematical operation
set1={1,2,3,4,5,6}
set2={4,5,6,7,8,9}
##union
union_set=set1.union(set2)
inter_set=set1.intersection(set2)
set1.intersection_update(set2)
print(set1)
# Out:
# {4, 5, 6}

# %%
print(set2.difference(set1))
print(set1.symmetric_difference(set2))
# Out:
# {8, 9, 7}
# {7, 8, 9}

# %%
##sets methods
set1={1,2,3,4,5}
set2={3,4,5}
print(set1.issubset(set2))
print(set1.issuperset(set2))
# Out:
# False
# True

# %%
lt=[1,2,2,3,3]
print(set(lt))
# Out:
# {1, 2, 3}

# %%
#counting unique words in text
text=" in this tutuorial we are discussing about sets"
words=text.split()
##convert list of words to set to get unique words
unique=set(words)
print(unique)
print(len(unique))
# Out:
# {'we', 'discussing', 'in', 'about', 'this', 'tutuorial', 'are', 'sets'}
# 8

# %%
print(text)
# Out:
#  in this tutuorial we are discussing about sets
